# %%
import pandas as pd
import yfinance as yf
import datetime
import time
import requests
import io
import random

start = datetime.datetime(2010,1,1)
end = datetime.datetime(2020,12,1)

url="https://pkgstore.datahub.io/core/nasdaq-listings/nasdaq-listed_csv/data/7665719fb51081ba0bd834fde71ce822/nasdaq-listed_csv.csv"
s = requests.get(url).content
companies = pd.read_csv(io.StringIO(s.decode('utf-8')))


symbols = companies['Symbol'].tolist()

random.seed(123)
Symbols = random.sample(symbols, 500)

# %%
stock_final = pd.DataFrame()

for i in Symbols:  
    try:
        stock = []
        stock = yf.download(i,start=start, end=end, progress=False)
        
        if len(stock) == 0:
            None
        else:
            stock['Name']= i
            stock_final = stock_final.append(stock,sort=False)
    except Exception:
        None
# Out:
# 1 Failed download:
# - ASEI: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - MCRL: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - FUEL: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - LDRH: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - INNL: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - ASBI: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - IMNP: No data found, symbol may be delisted
#
# 1 Failed download:
# - IILG: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BOBE: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - LBRKR: No data found, symbol may be delisted
#
# 1 Failed download:
# - BBEPP: No data found, symbol may be delisted
#
# 1 Failed download:
# - HPJ: No data found, symbol may be delisted
#
# 1 Failed download:
# - CADT: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - APRI: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - UNIS: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - SCOK: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - OHAI: No data found, symbol may be delisted
#
# 1 Failed download:
# - HDRAR: No data found, symbol may be delisted
#
# 1 Failed download:
# - PSEM: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - SPU: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - TRGT: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - PRAN: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - VNRCP: No data found, symbol may be delisted
#
# 1 Failed download:
# - THLD: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - POPE: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMCC: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - TRCB: No data found, symbol may be delisted
#
# 1 Failed download:
# - FSCFL: No data found, symbol may be delisted
#
# 1 Failed download:
# - IKGH: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - IMMY: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - ROIA: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - LONG: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - NTLS: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - IMI: No data found, symbol may be delisted
#
# 1 Failed download:
# - QLTI: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - PHII: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - ATRM: No data found, symbol may be delisted
#
# 1 Failed download:
# - WWWW: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - EZCH: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - OXLCN: No data found, symbol may be delisted
#
# 1 Failed download:
# - COVS: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - QUNR: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - NVSL: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - APSA: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CISG: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - NTK: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - GALTW: No data found, symbol may be delisted
#
# 1 Failed download:
# - STNR: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - AUXL: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - JACQ: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BONT: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - QTWW: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - YOD: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - WLB: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - REXI: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - FSGI: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - AMDA: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - WLRH: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - METR: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - IRDMZ: No data found, symbol may be delisted
#
# 1 Failed download:
# - THRX: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - TFSCU: No data found, symbol may be delisted
#
# 1 Failed download:
# - CSCD: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - MICTW: No data found, symbol may be delisted
#
# 1 Failed download:
# - VICL: No data found, symbol may be delisted
#
# 1 Failed download:
# - CMSB: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - PSBH: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - LMIA: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CNLMR: No data found, symbol may be delisted
#
# 1 Failed download:
# - TUBE: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - LNCO: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - IMRS: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - AUMAW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CLAC: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - UPIP: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - AGIIL: No data found, symbol may be delisted
#
# 1 Failed download:
# - NLNK: No data found, symbol may be delisted
#
# 1 Failed download:
# - MPEL: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - ALLB: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CRDC: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - ROSG: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CLDN: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CAMBW: No data found, symbol may be delisted
#
# 1 Failed download:
# - REMY: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - SBLKL: No data found, symbol may be delisted
#
# 1 Failed download:
# - VWR: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - AEPI: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - DRYS: No data found, symbol may be delisted
#
# 1 Failed download:
# - FWM: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BLVDU: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - SNTA: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - ROIAK: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - WTFCW: No data found, symbol may be delisted
#
# 1 Failed download:
# - ININ: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - PHIIK: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - TESO: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CERU: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - JOEZ: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - NVGN: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - JST: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - YDLE: No data found, symbol may be delisted
#
# 1 Failed download:
# - ENFC: No data found, symbol may be delisted
# 1 Failed download:
# - DAEG: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - MFLX: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - VLCCF: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - USMD: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - LEVYU: No data found, symbol may be delisted
#
# 1 Failed download:
# - ASBB: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - LMOS: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - NYNY: No data found, symbol may be delisted
#
# 1 Failed download:
# - IBCA: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - FES: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - SBSA: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - WFM: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - ZFGN: No data found, symbol may be delisted
#
# 1 Failed download:
# - ORPN: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - OKSB: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - KONA: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - SNAK: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - HTWR: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - LMCA: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - VTSS: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CTCM: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - APOL: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CSFL: No data found, symbol may be delisted
#
# 1 Failed download:
# - FXENP: No data found, symbol may be delisted
#
# 1 Failed download:
# - DRWIW: No data found, symbol may be delisted
#
# 1 Failed download:
# - HCBK: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BRDR: No data found, symbol may be delisted
#
# 1 Failed download:
# - DSKX: No data found, symbol may be delisted
#
# 1 Failed download:
# - NFEC: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CBF: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - DSCI: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - EFII: No data found, symbol may be delisted
#
# 1 Failed download:
# - VSCI: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - MBLX: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - ACXM: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - MELA: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - ELNK: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - VA: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - LOCM: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - APDNW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CARO: No data found, symbol may be delisted
#
# 1 Failed download:
# - TLMR: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - AREX: No data found, symbol may be delisted
#
# 1 Failed download:
# - CAPNW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CZFC: No data found, symbol may be delisted
#
# 1 Failed download:
# - CLTX: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BNCL: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMCN: No data found, symbol may be delisted
#
# 1 Failed download:
# - BWLD: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CNLMU: No data found, symbol may be delisted
#
# 1 Failed download:
# - MRD: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - WFD: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CBST: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BPFHP: No data found, symbol may be delisted
#
# 1 Failed download:
# - CISAW: No data found, symbol may be delisted
#
# 1 Failed download:
# - JDSU: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - EDS: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - FCS: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - INPH: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CMGE: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BOTA: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - ICLDW: No data found, symbol may be delisted
#
# 1 Failed download:
# - IPCM: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - EVLV: No data found, symbol may be delisted
#
# 1 Failed download:
# - ATML: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - RITTW: No data found, symbol may be delisted

# %%
close = stock_final[["Close", "Name"]]

close_wide = close.pivot_table(index="Date", columns='Name', values='Close')

stock_price = close_wide.dropna(axis = 1)

returns = stock_price.pct_change().iloc[1:]

returns.to_pickle('http://localhost:8888/tree/Desktop/returns.pkl')

# %%
returns_open = pd.read_pickle('returns.pkl')
returns_open
# Out:
# Name             AAL      ACAD      ACGL      ACTG      ACUR      ADMP  \
# Date
# 2010-01-04 -0.014463  0.030303  0.005591  0.070253  0.026266  0.000000
# 2010-01-05  0.113208 -0.014706 -0.003336 -0.029744 -0.032907 -0.031250
# 2010-01-06 -0.041431 -0.007463 -0.004323 -0.012685 -0.001890  0.064516
# 2010-01-07  0.029469  0.030075 -0.005882  0.031049 -0.005682  0.000000
# 2010-01-08 -0.019084  0.051095 -0.001972 -0.012461  0.003810  0.060606
# ...              ...       ...       ...       ...       ...       ...
# 2020-11-23  0.082203  0.005040  0.000589  0.010811  0.000000  0.000000
# 2020-11-24  0.092920  0.016345  0.016475  0.008021  0.037037  0.000000
# 2020-11-25  0.008097  0.020833 -0.028944  0.002653 -0.250000  0.048781
# 2020-11-27  0.002677  0.002506 -0.015499 -0.021164  0.190476  0.023256
# 2020-11-30 -0.056742  0.011786 -0.025129 -0.002703  0.000000 -0.022727
#
# Name            AEGN      AGNC      AINV      ALOT  ...       UNB      URBN  \
# Date                                                ...
# 2010-01-04  0.025088  0.006405  0.039832 -0.045576  ...  0.029499 -0.002286
# 2010-01-05 -0.018892 -0.003369  0.056452  0.004214  ...  0.000000  0.018619
# 2010-01-06 -0.003501 -0.012021  0.016221 -0.005594  ...  0.000000 -0.007874
# 2010-01-07  0.006588 -0.004943  0.008451  0.018284  ... -0.025788 -0.034014
# 2010-01-08 -0.010035  0.012610  0.015829  0.000000  ...  0.000000 -0.002054
# ...              ...       ...       ...       ...  ...       ...       ...
# 2020-11-23  0.046884  0.015779  0.026465  0.013238  ...  0.012554  0.044195
# 2020-11-24  0.043084  0.016181  0.024862 -0.004020  ...  0.046106 -0.048642
# 2020-11-25 -0.017391 -0.003185 -0.003594 -0.009082  ...  0.020370 -0.011952
# 2020-11-27 -0.019358 -0.005112  0.001803  0.018330  ... -0.018149 -0.023858
# 2020-11-30 -0.032713 -0.018626 -0.023402  0.003000  ... -0.021811 -0.057487
#
# Name            VCIT       VOD      WHLM      WSBC      WSBF      WSTG  \
# Date
# 2010-01-04  0.003605  0.004331  0.000000  0.032415  0.151220  0.000000
# 2010-01-05  0.006652 -0.007331  0.111111 -0.032967  0.016949  0.001258
# 2010-01-06 -0.002115 -0.007819  0.000000 -0.017857 -0.070833 -0.012563
# 2010-01-07  0.003179 -0.018827  0.000000  0.056198  0.067265  0.011450
# 2010-01-08  0.001056 -0.015172  0.000000  0.028951  0.042017  0.006289
# ...              ...       ...       ...       ...       ...       ...
# 2020-11-23 -0.000207 -0.004857  0.058659  0.019130  0.004978 -0.038937
# 2020-11-24  0.000414  0.028676 -0.002639  0.049829  0.024216  0.007150
# 2020-11-25  0.001241 -0.005931 -0.007937 -0.020806 -0.013434  0.000947
# 2020-11-27  0.001652  0.005370  0.013333 -0.012284 -0.018519  0.024586
# 2020-11-30  0.001753 -0.016024  0.010526 -0.037647 -0.024972 -0.035994
#
# Name            XOMA      ZUMZ
# Date
# 2010-01-04  0.000000 -0.028302
# 2010-01-05 -0.014286 -0.005663
# 2010-01-06  0.014493  0.031733
# 2010-01-07 -0.014286  0.156151
# 2010-01-08  0.014493  0.004775
# ...              ...       ...
# 2020-11-23  0.010710  0.039712
# 2020-11-24 -0.016046  0.019375
# 2020-11-25  0.004923 -0.001086
# 2020-11-27 -0.018677  0.016852
# 2020-11-30  0.033073 -0.008554
#
# [2747 rows x 198 columns]
